# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path_excel = os.path.join("/home", "kathrin", "dev_ws", "csv_files", "new-method")
filenames = {"apriltag mot 50mm" : "data_apriltag.xlsx",
             "apriltag mot 150mm": "data_apriltag_150mm.xlsx",
             "apriltag mog3"     : "data_apriltag_50mm_mog3.xlsx",
             "apriltag mog5"     : "data_apriltag_50mm_mog5.xlsx",
             "aruco mot 50mm"    : "data_aruco.xlsx",
             "aruco mot 150mm"   : "data_aruco_150mm.xlsx",
             "aruco mog3"        : "data_aruco_50mm_mog3.xlsx",
             "aruco mog5"        : "data_aruco_50mm_mog3.xlsx"}

# %%
dataframes = dict()
for key in filenames:
    dataframes[key] = pd.read_excel(os.path.join(path_excel, filenames[key]))

# %%
for bib in ["apriltag", "aruco"]:
    for impr_mthd in ["mot 50mm", "mot 150mm"]:
        
        dataframe = dataframes[f"{bib} {impr_mthd}"]
        columns = list()
            
        for tr in ["trans", "rot"]:
            for ax in ["x", "y", "z"]:
                
                columns.append(f"{tr} {ax} original")


                for outlier_detector in ["z2", "z3", "iqr"]:
                
            #print(dataframes[f"{bib} {impr_mthd}"][["trans x original", "trans y original"]])#, f"rot y {impr_mthd.replace(' 50mm', '3').replace(' 150mm', '3')}"])
    
    for impr_mthd in ["mog3", "mog5"]:
        # do something
# Out:
#       trans x original  trans y original
# 0             0.000000          0.000000
# 1            -0.006898         -0.001080
# 2            -0.006901         -0.001076
# 3            -0.006899         -0.001080
# 4            -0.006892         -0.001085
# ...                ...               ...
# 6190         -0.038867         -0.010092
# 6191         -0.033677         -0.008830
# 6192         -0.039513         -0.010149
# 6193         -0.050598         -0.013269
# 6194         -0.037473         -0.009712
#
# [6195 rows x 2 columns]
#       trans x original  trans y original
# 0             0.000000          0.000000
# 1            -0.006898         -0.001080
# 2            -0.006901         -0.001076
# 3            -0.006899         -0.001080
# 4            -0.006892         -0.001085
# ...                ...               ...
# 6190         -0.038867         -0.010092
# 6191         -0.033677         -0.008830
# 6192         -0.039513         -0.010149
# 6193         -0.050598         -0.013269
# 6194         -0.037473         -0.009712
#
# [6195 rows x 2 columns]
#       trans x original  trans y original
# 0             0.000000          0.000000
# 1            -0.006898         -0.001080
# 2            -0.006901         -0.001076
# 3            -0.006899         -0.001080
# 4            -0.006892         -0.001085
# ...                ...               ...
# 6190         -0.038867         -0.010092
# 6191         -0.033677         -0.008830
# 6192         -0.039513         -0.010149
# 6193         -0.050598         -0.013269
# 6194         -0.037473         -0.009712
#
# [6195 rows x 2 columns]
#       trans x original  trans y original
# 0             0.000000          0.000000
# 1            -0.038635         -0.007167
# 2            -0.038656         -0.007220
# 3            -0.038625         -0.007066
# 4            -0.038660         -0.007216
# ...                ...               ...
# 9390         -0.006604         -0.001180
# 9391         -0.006595         -0.001187
# 9392         -0.006594         -0.001183
# 9393         -0.006595         -0.001184
# 9394         -0.006594         -0.001179
#
# [9395 rows x 2 columns]
#       trans x original  trans y original
# 0             0.000000          0.000000
# 1            -0.038635         -0.007167
# 2            -0.038656         -0.007220
# 3            -0.038625         -0.007066
# 4            -0.038660         -0.007216
# ...                ...               ...
# 9390         -0.006604         -0.001180
# 9391         -0.006595         -0.001187
# 9392         -0.006594         -0.001183
# 9393         -0.006595         -0.001184
# 9394         -0.006594         -0.001179
#
# [9395 rows x 2 columns]
#       trans x original  trans y original
# 0             0.000000          0.000000
# 1            -0.038635         -0.007167
# 2            -0.038656         -0.007220
# 3            -0.038625         -0.007066
# 4            -0.038660         -0.007216
# ...                ...               ...
# 9390         -0.006604         -0.001180
# 9391         -0.006595         -0.001187
# 9392         -0.006594         -0.001183
# 9393         -0.006595         -0.001184
# 9394         -0.006594         -0.001179
#
# [9395 rows x 2 columns]
#       trans x original  trans y original
# 0                  0.0               0.0
# 1                  NaN               NaN
# 2                  NaN               NaN
# 3                  NaN               NaN
# 4                  NaN               NaN
# ...                ...               ...
# 4340               NaN               NaN
# 4341               NaN               NaN
# 4342               NaN               NaN
# 4343               NaN               NaN
# 4344               NaN               NaN
#
# [4345 rows x 2 columns]
#       trans x original  trans y original
# 0                  0.0               0.0
# 1                  NaN               NaN
# 2                  NaN               NaN
# 3                  NaN               NaN
# 4                  NaN               NaN
# ...                ...               ...
# 4340               NaN               NaN
# 4341               NaN               NaN
# 4342               NaN               NaN
# 4343               NaN               NaN
# 4344               NaN               NaN
#
# [4345 rows x 2 columns]
#       trans x original  trans y original
# 0                  0.0               0.0
# 1                  NaN               NaN
# 2                  NaN               NaN
# 3                  NaN               NaN
# 4                  NaN               NaN
# ...                ...               ...
# 4340               NaN               NaN
# 4341               NaN               NaN
# 4342               NaN               NaN
# 4343               NaN               NaN
# 4344               NaN               NaN
#
# [4345 rows x 2 columns]
#       trans x original  trans y original
# 0                  0.0               0.0
# 1                  NaN               NaN
# 2                  NaN               NaN
# 3                  NaN               NaN
# 4                  NaN               NaN
# ...                ...               ...
# 3848               NaN               NaN
# 3849               NaN               NaN
# 3850               NaN               NaN
# 3851               NaN               NaN
# 3852               NaN               NaN
#
# [3853 rows x 2 columns]
#       trans x original  trans y original
# 0                  0.0               0.0
# 1                  NaN               NaN
# 2                  NaN               NaN
# 3                  NaN               NaN
# 4                  NaN               NaN
# ...                ...               ...
# 3848               NaN               NaN
# 3849               NaN               NaN
# 3850               NaN               NaN
# 3851               NaN               NaN
# 3852               NaN               NaN
#
# [3853 rows x 2 columns]
#       trans x original  trans y original
# 0                  0.0               0.0
# 1                  NaN               NaN
# 2                  NaN               NaN
# 3                  NaN               NaN
# 4                  NaN               NaN
# ...                ...               ...
# 3848               NaN               NaN
# 3849               NaN               NaN
# 3850               NaN               NaN
# 3851               NaN               NaN
# 3852               NaN               NaN
#
# [3853 rows x 2 columns]
#       trans x original  trans y original
# 0             0.000000          0.000000
# 1            -0.007243         -0.001337
# 2            -0.007159         -0.001340
# 3            -0.007338         -0.001202
# 4            -0.007144         -0.001030
# ...                ...               ...
# 6040         -0.042941         -0.012249
# 6041         -0.042941         -0.012249
# 6042         -0.042941         -0.012249
# 6043         -0.042941         -0.012249
# 6044         -0.042872         -0.012241
#
# [6045 rows x 2 columns]
#       trans x original  trans y original
# 0             0.000000          0.000000
# 1            -0.007243         -0.001337
# 2            -0.007159         -0.001340
# 3            -0.007338         -0.001202
# 4            -0.007144         -0.001030
# ...                ...               ...
# 6040         -0.042941         -0.012249
# 6041         -0.042941         -0.012249
# 6042         -0.042941         -0.012249
# 6043         -0.042941         -0.012249
# 6044         -0.042872         -0.012241
#
# [6045 rows x 2 columns]
#       trans x original  trans y original
# 0             0.000000          0.000000
# 1            -0.007243         -0.001337
# 2            -0.007159         -0.001340
# 3            -0.007338         -0.001202
# 4            -0.007144         -0.001030
# ...                ...               ...
# 6040         -0.042941         -0.012249
# 6041         -0.042941         -0.012249
# 6042         -0.042941         -0.012249
# 6043         -0.042941         -0.012249
# 6044         -0.042872         -0.012241
#
# [6045 rows x 2 columns]
#        trans x original  trans y original
# 0              0.000000          0.000000
# 1             -0.039531         -0.007788
# 2             -0.039531         -0.007788
# 3             -0.039531         -0.007788
# 4             -0.039012         -0.008740
# ...                 ...               ...
# 11331         -0.006876         -0.001396
# 11332         -0.006876         -0.001396
# 11333         -0.006876         -0.001396
# 11334         -0.006876         -0.001396
# 11335         -0.006876         -0.001396
#
# [11336 rows x 2 columns]
#        trans x original  trans y original
# 0              0.000000          0.000000
# 1             -0.039531         -0.007788
# 2             -0.039531         -0.007788
# 3             -0.039531         -0.007788
# 4             -0.039012         -0.008740
# ...                 ...               ...
# 11331         -0.006876         -0.001396
# 11332         -0.006876         -0.001396
# 11333         -0.006876         -0.001396
# 11334         -0.006876         -0.001396
# 11335         -0.006876         -0.001396
#
# [11336 rows x 2 columns]
#        trans x original  trans y original
# 0              0.000000          0.000000
# 1             -0.039531         -0.007788
# 2             -0.039531         -0.007788
# 3             -0.039531         -0.007788
# 4             -0.039012         -0.008740
# ...                 ...               ...
# 11331         -0.006876         -0.001396
# 11332         -0.006876         -0.001396
# 11333         -0.006876         -0.001396
# 11334         -0.006876         -0.001396
# 11335         -0.006876         -0.001396
#
# [11336 rows x 2 columns]
#       trans x original  trans y original
# 0                  0.0               0.0
# 1                  NaN               NaN
# 2                  NaN               NaN
# 3                  NaN               NaN
# 4                  NaN               NaN
# ...                ...               ...
# 6182               NaN               NaN
# 6183               NaN               NaN
# 6184               NaN               NaN
# 6185               NaN               NaN
# 6186               NaN               NaN
#
# [6187 rows x 2 columns]
#       trans x original  trans y original
# 0                  0.0               0.0
# 1                  NaN               NaN
# 2                  NaN               NaN
# 3                  NaN               NaN
# 4                  NaN               NaN
# ...                ...               ...
# 6182               NaN               NaN
# 6183               NaN               NaN
# 6184               NaN               NaN
# 6185               NaN               NaN
# 6186               NaN               NaN
#
# [6187 rows x 2 columns]
#       trans x original  trans y original
# 0                  0.0               0.0
# 1                  NaN               NaN
# 2                  NaN               NaN
# 3                  NaN               NaN
# 4                  NaN               NaN
# ...                ...               ...
# 6182               NaN               NaN
# 6183               NaN               NaN
# 6184               NaN               NaN
# 6185               NaN               NaN
# 6186               NaN               NaN
#
# [6187 rows x 2 columns]
#       trans x original  trans y original
# 0                  0.0               0.0
# 1                  NaN               NaN
# 2                  NaN               NaN
# 3                  NaN               NaN
# 4                  NaN               NaN
# ...                ...               ...
# 6182               NaN               NaN
# 6183               NaN               NaN
# 6184               NaN               NaN
# 6185               NaN               NaN
# 6186               NaN               NaN
#
# [6187 rows x 2 columns]
#       trans x original  trans y original
# 0                  0.0               0.0
# 1                  NaN               NaN
# 2                  NaN               NaN
# 3                  NaN               NaN
# 4                  NaN               NaN
# ...                ...               ...
# 6182               NaN               NaN
# 6183               NaN               NaN
# 6184               NaN               NaN
# 6185               NaN               NaN
# 6186               NaN               NaN
#
# [6187 rows x 2 columns]
#       trans x original  trans y original
# 0                  0.0               0.0
# 1                  NaN               NaN
# 2                  NaN               NaN
# 3                  NaN               NaN
# 4                  NaN               NaN
# ...                ...               ...
# 6182               NaN               NaN
# 6183               NaN               NaN
# 6184               NaN               NaN
# 6185               NaN               NaN
# 6186               NaN               NaN
#
# [6187 rows x 2 columns]
